# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('all_anime.csv')

# %%
data
# Out:
#           Unnamed: 0  user_id  anime_id  rating  watching_status  \
# 0                  0        0      7173     0.0                4
# 1                  1        0      5323     0.0                2
# 2                  2        0      5028     0.0                2
# 3                  3        0      1048     0.0                4
# 4                  4        0     12221     0.0                2
# ...              ...      ...       ...     ...              ...
# 20842196    20842196    79300      3999     4.5                1
# 20842197    20842197    79300      8535     4.5                1
# 20842198    20842198    79300      6646     3.0                3
# 20842199    20842199    79300      5765     4.0                1
# 20842200    20842200    79300      5926     4.5                1
#
#           watched_episodes                                               Name  \
# 0                        0               Haikyuu!! Movie 2: Shousha to Haisha
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20842201 entries, 0 to 20842200
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Unnamed: 0        int64
#  1   user_id           int64
#  2   anime_id          int64
#  3   rating            float64
#  4   watching_status   int64
#  5   watched_episodes  int64
#  6   Name              object
#  7   Tags              object
# dtypes: float64(1), int64(5), object(2)
# memory usage: 1.2+ GB

# %%
data.describe()
# Out:
#          Unnamed: 0       user_id      anime_id        rating  \
# count  2.084220e+07  2.084220e+07  2.084220e+07  2.084220e+07
# mean   1.042110e+07  3.984237e+04  4.826288e+03  1.747458e+00
# std    6.016625e+06  2.285348e+04  3.823595e+03  2.005187e+00
# min    0.000000e+00  0.000000e+00  2.000000e+00  0.000000e+00
# 25%    5.210550e+06  1.983300e+04  1.549000e+03  0.000000e+00
# 50%    1.042110e+07  4.032900e+04  4.207000e+03  0.000000e+00
# 75%    1.563165e+07  5.936700e+04  7.123000e+03  4.000000e+00
# max    2.084220e+07  7.930000e+04  1.736500e+04  6.000000e+00
#
#        watching_status  watched_episodes
# count     2.084220e+07      2.084220e+07
# mean      2.436974e+00      1.716115e+00
# std       1.713224e+00      2.510919e+01
# min       0.000000e+00      0.000000e+00
# 25%       1.000000e+00      0.000000e+00
# 50%       1.000000e+00      0.000000e+00
# 75%       4.000000e+00      0.000000e+00
# max       6.000000e+00      2.605000e+03

# %%
data.isnull().sum()
# Out:
# Unnamed: 0             0
# user_id                0
# anime_id               0
# rating                 0
# watching_status        0
# watched_episodes       0
# Name                1508
# Tags                1508
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# user_id             0
# anime_id            0
# rating              0
# watching_status     0
# watched_episodes    0
# Name                0
# Tags                0
# dtype: int64

# %%
data.drop_duplicates(inplace=True)

# %%
data = data.drop(['Unnamed: 0'], axis=1)

# %%
data
# Out:
#           user_id  anime_id  rating  watching_status  watched_episodes  \
# 0               0      7173     0.0                4                 0
# 1               0      5323     0.0                2                 1
# 2               0      5028     0.0                2                 5
# 3               0      1048     0.0                4                 0
# 4               0     12221     0.0                2                 4
# ...           ...       ...     ...              ...               ...
# 20842196    79300      3999     4.5                1                 0
# 20842197    79300      8535     4.5                1                 0
# 20842198    79300      6646     3.0                3                 2
# 20842199    79300      5765     4.0                1                 0
# 20842200    79300      5926     4.5                1                 0
#
#                                                        Name  \
# ...

# %%
new_feature = ['anime_id', 'user_id', 'Name', 'Tags', 'watching_status', 'watched_episodes', 'rating']

data = data.reindex(columns=new_feature)
data
# Out:
#           anime_id  user_id  \
# 0             7173        0
# 1             5323        0
# 2             5028        0
# 3             1048        0
# 4            12221        0
# ...            ...      ...
# 20842196      3999    79300
# 20842197      8535    79300
# 20842198      6646    79300
# 20842199      5765    79300
# 20842200      5926    79300
#
#                                                        Name  \
# 0                      Haikyuu!! Movie 2: Shousha to Haisha
# 1                                           Attack on Titan
# 2                                         My Little Monster
# 3                                                Death Note
# 4                                  Fruits Basket 1st Season
# ...                                                     ...
# 20842196                                         Bakuman. 2
# 20842197                                 Tsuredure Children
# 20842198                                          Shirobako
# ...

# %% [markdown]
# watching status :
# 1 : Watched
# 2 : Watching
# 3 : Dropped
# 4 : Want to Watch
# 5 : Stalled
# 6 : Wont Watch

# %%
data.describe()
# Out:
#            anime_id       user_id  watching_status  watched_episodes  \
# count  2.084069e+07  2.084069e+07     2.084069e+07      2.084069e+07
# mean   4.825386e+03  3.984177e+04     2.436816e+00      1.716238e+00
# std    3.822263e+03  2.285367e+04     1.713141e+00      2.511009e+01
# min    2.000000e+00  0.000000e+00     0.000000e+00      0.000000e+00
# 25%    1.549000e+03  1.983300e+04     1.000000e+00      0.000000e+00
# 50%    4.207000e+03  4.032900e+04     1.000000e+00      0.000000e+00
# 75%    7.122000e+03  5.936700e+04     4.000000e+00      0.000000e+00
# max    1.723100e+04  7.930000e+04     6.000000e+00      2.605000e+03
#
#              rating
# count  2.084069e+07
# mean   1.747571e+00
# std    2.005204e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    4.000000e+00
# max    6.000000e+00

# %%
watching_status_sum = (data.watching_status == 0).sum()
watched_episodes_sum = (data.watched_episodes == 0).sum()
rating_sum = (data.rating == 0).sum()

print("watching_status 0 values : ", watching_status_sum)
print("watched_episodes 0 value : ", watched_episodes_sum)
print("rating 0 values : ", rating_sum)
# Out:
# watching_status 0 values :  3258
# watched_episodes 0 value :  19173100
# rating 0 values :  11148209

# %%
data.loc[(data['watching_status'] == 0)]
# Out:
#         anime_id  user_id                                    Name  \
# 10954         99       32                             Dragon Ball
# 10955         55       32                         Hunter x Hunter
# 10956         22       32                                  Naruto
# 10957        172       32           Hajime no Ippo: The Fighting!
# 10958       3480       32                        Infinite Stratos
# ...          ...      ...                                     ...
# 115173       920      438   Dragon Ball Z Movie 9: Bojack Unbound
# 115174      1367      438                        Nanatsuiro Drops
# 115175      1505      438  Dragon Ball Movie 4: The Path to Power
# 117616     10118      448                  The Promised Neverland
# 117617      7585      448                        My Hero Academia
#
#                                                      Tags  watching_status  \
# 10954   Action, Adventure, Comedy, Shounen, Journey to...                0
# ...

# %%
data.loc[(data['watched_episodes'] == 0)]
# Out:
#           anime_id  user_id  \
# 0             7173        0
# 3             1048        0
# 6              147        0
# 8             3977        0
# 9             4685        1
# ...            ...      ...
# 20842195      1078    79300
# 20842196      3999    79300
# 20842197      8535    79300
# 20842199      5765    79300
# 20842200      5926    79300
#
#                                                        Name  \
# 0                      Haikyuu!! Movie 2: Shousha to Haisha
# 3                                                Death Note
# 6                                             Fruits Basket
# 8                                              Future Diary
# 9                                    Dusk Maiden of Amnesia
# ...                                                     ...
# 20842195                         Tengen Toppa Gurren Lagann
# 20842196                                         Bakuman. 2
# 20842197                                 Tsuredure Children
# ...

# %%
data.loc[(data['rating'] == 0)]
# Out:
#           anime_id  user_id  \
# 0             7173        0
# 1             5323        0
# 2             5028        0
# 3             1048        0
# 4            12221        0
# ...            ...      ...
# 20842169      3347    79300
# 20842174      8111    79300
# 20842189      6694    79300
# 20842192       851    79300
# 20842195      1078    79300
#
#                                                        Name  \
# 0                      Haikyuu!! Movie 2: Shousha to Haisha
# 1                                           Attack on Titan
# 2                                         My Little Monster
# 3                                                Death Note
# 4                                  Fruits Basket 1st Season
# ...                                                     ...
# 20842169                                   Future Diary OVA
# 20842174                                 Pokemon Sun & Moon
# 20842189  JoJo’s Bizarre Adventure: Stardust Crusaders -...
# ...

# %%
data = data.loc[(data[['watching_status', 'watched_episodes', 'rating']] != 0).all(axis=1)]
data.shape
data
# Out:
#           anime_id  user_id                             Name  \
# 12            1061        1                       Heroic Age
# 28            2375        1  Mazinger Edition Z: The Impact!
# 36            2764        1                        Chu-Bra!!
# 41            4683        1                      Fate/Zero 2
# 43            1333        1                     Sky Girls TV
# ...            ...      ...                              ...
# 20842079      8988    79300           Hakata Tonkotsu Ramens
# 20842099      8894    79300     Katana Maidens: Toji no Miko
# 20842113      8312    79300  Boruto: Naruto Next Generations
# 20842165      9540    79300    Today's Menu for Emiya Family
# 20842198      6646    79300                        Shirobako
#
#                                                        Tags  watching_status  \
# 12        Action, Adventure, Mecha, Sci Fi, Aliens, Mili...                5
# ...

# %%
data.describe()
# Out:
#             anime_id        user_id  watching_status  watched_episodes  \
# count  811860.000000  811860.000000    811860.000000     811860.000000
# mean     4784.734484   39844.458521         3.165079         31.124836
# std      4058.677791   22964.352262         1.167819        108.908083
# min         2.000000       1.000000         2.000000          1.000000
# 25%      1188.000000   19951.000000         2.000000          2.000000
# 50%      3999.000000   40158.000000         3.000000          5.000000
# 75%      7283.000000   59449.000000         5.000000         12.000000
# max     17114.000000   79300.000000         5.000000       2605.000000
#
#               rating
# count  811860.000000
# mean        3.173130
# std         1.243848
# min         0.500000
# 25%         2.500000
# 50%         3.500000
# 75%         4.000000
# max         5.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 811860 entries, 12 to 20842198
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   anime_id          811860 non-null  int64
#  1   user_id           811860 non-null  int64
#  2   Name              811860 non-null  object
#  3   Tags              811860 non-null  object
#  4   watching_status   811860 non-null  int64
#  5   watched_episodes  811860 non-null  int64
#  6   rating            811860 non-null  float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 49.6+ MB

# %%
data.isnull().sum()
# Out:
# anime_id            0
# user_id             0
# Name                0
# Tags                0
# watching_status     0
# watched_episodes    0
# rating              0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data
# Out:
#           anime_id  user_id                             Name  \
# 12            1061        1                       Heroic Age
# 28            2375        1  Mazinger Edition Z: The Impact!
# 36            2764        1                        Chu-Bra!!
# 41            4683        1                      Fate/Zero 2
# 43            1333        1                     Sky Girls TV
# ...            ...      ...                              ...
# 20842079      8988    79300           Hakata Tonkotsu Ramens
# 20842099      8894    79300     Katana Maidens: Toji no Miko
# 20842113      8312    79300  Boruto: Naruto Next Generations
# 20842165      9540    79300    Today's Menu for Emiya Family
# 20842198      6646    79300                        Shirobako
#
#                                                        Tags  watching_status  \
# 12        Action, Adventure, Mecha, Sci Fi, Aliens, Mili...                5
# ...

# %%
data.to_csv('all_anime_clean.csv')

# %%
data_clean = pd.read_csv("all_anime_clean.csv")

# %%
data_clean
# Out:
#         Unnamed: 0  anime_id  user_id                             Name  \
# 0               12      1061        1                       Heroic Age
# 1               28      2375        1  Mazinger Edition Z: The Impact!
# 2               36      2764        1                        Chu-Bra!!
# 3               41      4683        1                      Fate/Zero 2
# 4               43      1333        1                     Sky Girls TV
# ...            ...       ...      ...                              ...
# 811855    20842079      8988    79300           Hakata Tonkotsu Ramens
# 811856    20842099      8894    79300     Katana Maidens: Toji no Miko
# 811857    20842113      8312    79300  Boruto: Naruto Next Generations
# 811858    20842165      9540    79300    Today's Menu for Emiya Family
# 811859    20842198      6646    79300                        Shirobako
#
#                                                      Tags  watching_status  \
# ...
